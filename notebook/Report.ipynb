# %% [markdown]
# # <div style="text-align:center"><u>REPORT:</u> Technical interview proposed by Jolimoi</div>

# %% [markdown]
# ## <div style="text-align:center;"><u>DATA:</u> Title, artist, date, and medium of every artwork in the MoMA collection</div>

# %% [markdown]
# ### <u>Some Context:</u>

# %% [markdown]
# Here Some Context

# %% [markdown]
# ### <u>Which artist in this data set lived the longest?</u>

# %% [markdown]
# <strong>Boris Efimov</strong>, a Russian cartoonist, born on September 28, <em>1900</em> and died on October 1, <em>2008</em>, is the oldest artist in the dataset at <strong>108</strong> years of age.

# %% [markdown]
# ![Boris Efimov](files/bo.jpg)

# %% [markdown]
# ### <u>Who are the top 10 artists by the number of artworks?</u>

# %%
import files.utils as utils

# %%
utils.topTenArtists()

# %% [markdown]
# ### <u>Which artist has created the most artwork by total surface area?</u>

# %% [markdown]
# We have focused on 2D artworks to avoid misclassification.

# %%
utils.topTenArtistsByArea()

# %% [markdown]
# <strong>Ludwig Mies van der Rohe</strong> is clearly the one who produced the most artwork with a total of <strong>735.05 m²</strong> of 2D art.
